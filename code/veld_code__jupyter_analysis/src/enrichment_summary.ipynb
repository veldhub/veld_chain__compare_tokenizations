# %% [markdown]
# # setup

# %%
from lxml import etree
import pandas as pd

# %%
# !ls /veld/input/xmlanntools/
# Out:
# DEU100.ann.json  DEU100.conllu	DEU100.txt
# DEU100.ann.xml	 DEU100.json	DEU100.xml

# %%
# !ls /veld/input/teitok/
# Out:
# DEU100.xml  DEU100_tokenized.xml  DEU100_tokenized_parsed.xml

# %%
root_xmlanntools = etree.parse("/veld/input/xmlanntools/DEU100.ann.xml").getroot()
root_teitok = etree.parse("/veld/input/teitok/DEU100_tokenized_parsed.xml").getroot()

# %%
def search_xpath(root, xpath):
    return root.xpath(xpath, namespaces={"xmlns": "http://www.tei-c.org/ns/1.0"})

# %% [markdown]
# # create data structure for all linguistic annotation data

# %%
def get_attrib_count(root, xpath):
    attrib_count = {}
    attrib_key_list = ["token", "lemma", "upos", "xpos", "deprel", "feats"]
    for attrib_key in attrib_key_list:
        attrib_count[attrib_key] = {}
    for t in search_xpath(root, xpath):
        for attrib_key in attrib_key_list:
            if attrib_key == "token":
                token = t.text
                token_count = attrib_count[attrib_key].get(token, 0)
                attrib_count[attrib_key][token] = token_count + 1
            elif attrib_key == "feats":
                token_attrib_value = t.attrib.get(attrib_key)
                if token_attrib_value:
                    feats_tmp = token_attrib_value.split("|")
                    for feat in feats_tmp:
                        feats_split = feat.split("=")
                        if len(feats_split) == 2:
                            feat_key, feat_value = feats_split
                            if feat_key not in attrib_count[attrib_key]:
                                attrib_count[attrib_key][feat_key] = {}
                            feat_value_count = attrib_count[attrib_key][feat_key].get(feat_value, 0)
                            attrib_count[attrib_key][feat_key][feat_value] = feat_value_count + 1
            else:
                token_attrib_value = t.attrib[attrib_key]
                attrib_value_count = attrib_count[attrib_key].get(token_attrib_value, 0)
                attrib_count[attrib_key][token_attrib_value] = attrib_value_count + 1
    return attrib_count

attrib_count_xmlanntools = get_attrib_count(root_xmlanntools, "//xmlns:w")
attrib_count_teitok = get_attrib_count(root_teitok, "//xmlns:tok")

# %% [markdown]
# # count of tokens

# %%
def count_tokens():
    print("xmlanntools:", len(search_xpath(root_xmlanntools, "//xmlns:w")))
    print("teitok:", len(search_xpath(root_teitok, "//xmlns:tok")))

count_tokens()
# Out:
# xmlanntools: 49724
# teitok: 51743

# %% [markdown]
# # count of sentences

# %%
def count_sentences():
    print("xmlanntools:", len(search_xpath(root_xmlanntools, "//xmlns:s")))
    print("teitok:", len(search_xpath(root_teitok, "//xmlns:s")))

count_sentences()
# Out:
# xmlanntools: 2869
# teitok: 3373

# %% [markdown]
# # convert to dataframe for visual comparison

# %%
def convert_to_summary_df(attrib_count_xmlanntools, attrib_count_teitok, key): 

    def get_indices_sorted(l):
        l_indexed = [[i, v] for i, v in enumerate(l)]
        l_indexed = sorted(l_indexed, key=lambda x : -x[1])
        l_sorted = [l_i[0] for l_i in l_indexed]
        return l_sorted

    def convert_to_summary_lists(attrib_count, sub_key_list):
        count_abs_list = []
        count_rel_list = []
        count_sum = sum(v for v in attrib_count_xmlanntools[key].values())
        for sub_key in sub_key_list:
            abs_count = attrib_count[key].get(sub_key, 0)
            count_abs_list.append(abs_count)
            if count_sum != 0:
                count_rel_list.append(round(100 / count_sum * abs_count, 2))
            else:
                count_rel_list.append(0)
        return count_abs_list, count_rel_list

    if key not in attrib_count_xmlanntools:
        attrib_count_xmlanntools[key] = {}
    if key not in attrib_count_teitok:
        attrib_count_teitok[key] = {}
    sub_key_list = list(set(attrib_count_xmlanntools[key].keys()) | set(attrib_count_teitok[key].keys()))
    count_abs_list_xmlanntools, count_rel_list_xmlanntools = convert_to_summary_lists(attrib_count_xmlanntools, sub_key_list)
    count_abs_list_teitok, count_rel_list_teitok = convert_to_summary_lists(attrib_count_teitok, sub_key_list)
    avg_count_list = [(cx + ct) / 2 for cx, ct in zip(count_abs_list_xmlanntools, count_abs_list_teitok)]
    avg_count_list_sorted_indices = get_indices_sorted(avg_count_list)   
    df_data = {
        key: [sub_key_list[i] for i in avg_count_list_sorted_indices], 
        f"xmlanntools: absolute count": [count_abs_list_xmlanntools[i] for i in avg_count_list_sorted_indices], 
        f"xmlanntools: percentage": [count_rel_list_xmlanntools[i] for i in avg_count_list_sorted_indices],
        f"teitok: absolute count": [count_abs_list_teitok[i] for i in avg_count_list_sorted_indices], 
        f"teitok: percentage": [count_rel_list_teitok[i] for i in avg_count_list_sorted_indices],
        f"both: average absolute count": [avg_count_list[i] for i in avg_count_list_sorted_indices],
    }
    return pd.DataFrame(df_data)

# %% [markdown]
# # upos (universal part of speech)

# %%
convert_to_summary_df(attrib_count_xmlanntools, attrib_count_teitok, "upos")
# Out:
#      upos  xmlanntools: absolute count  xmlanntools: percentage  \
# 0   PUNCT                         7495                    15.07
# 1    NOUN                         7560                    15.20
# 2    PRON                         7105                    14.29
# 3    VERB                         5653                    11.37
# 4     DET                         4273                     8.59
# 5     ADP                         3964                     7.97
# 6     ADJ                         3743                     7.53
# 7     ADV                         2490                     5.01
# 8     AUX                         2179                     4.38
# 9   CCONJ                         2091                     4.21
# 10  PROPN                         1651                     3.32
# 11   PART                          721                     1.45
# 12  SCONJ                          598                     1.20
# 13      X                          104                     0.21
# 14    NUM                           59                     0.12
# 15   INTJ                           38                     0.08
#
#     teitok: absolute count  teitok: percentage  both: average absolute count
# 0                     9536               19.18                        8515.5
# 1                     7209               14.50                        7384.5
# 2                     7204               14.49                        7154.5
# 3                     5757               11.58                        5705.0
# 4                     4264                8.58                        4268.5
# 5                     3981                8.01                        3972.5
# 6                     3728                7.50                        3735.5
# 7                     2516                5.06                        2503.0
# 8                     2241                4.51                        2210.0
# 9                     2119                4.26                        2105.0
# 10                    1600                3.22                        1625.5
# 11                     749                1.51                         735.0
# 12                     607                1.22                         602.5
# 13                     116                0.23                         110.0
# 14                      62                0.12                          60.5
# 15                      54                0.11                          46.0

# %% [markdown]
# # xpos (extended part of speech)

# %%
convert_to_summary_df(attrib_count_xmlanntools, attrib_count_teitok, "xpos")
# Out:
#        xpos  xmlanntools: absolute count  xmlanntools: percentage  \
# 0        NN                         7546                    15.18
# 1        $.                         3327                     6.69
# 2        $,                         4161                     8.37
# 3      PPER                         3917                     7.88
# 4       ART                         3853                     7.75
# 5     VVFIN                         3729                     7.50
# 6      APPR                         2978                     5.99
# 7       ADV                         2153                     4.33
# 8      ADJA                         2168                     4.36
# 9       KON                         1787                     3.59
# 10       NE                         1651                     3.32
# 11     ADJD                         1518                     3.05
# 12    VAFIN                         1444                     2.90
# 13   PPOSAT                         1220                     2.45
# 14     VVPP                          934                     1.88
# 15    VVINF                          890                     1.79
# 16    PRELS                          708                     1.42
# 17      PRF                          600                     1.21
# 18     KOUS                          532                     1.07
# 19    PTKVZ                          506                     1.02
# 20    VMFIN                          473                     0.95
# 21  APPRART                          445                     0.89
# 22   PTKNEG                          432                     0.87
# 23      PIS                          350                     0.70
# 24    KOKOM                          304                     0.61
# 25    PTKZU                          289                     0.58
# 26      PDS                          195                     0.39
# 27     PWAV                          169                     0.34
# 28     PIAT                          164                     0.33
# 29    PIDAT                          154                     0.31
# 30    VAINF                          140                     0.28
# 31     PDAT                          137                     0.28
# 32    PROAV                          131                     0.26
# 33      PWS                          115                     0.23
# 34       FM                           98                     0.20
# 35     VAPP                           74                     0.15
# 36     KOUI                           66                     0.13
# 37    VVIZU                           66                     0.13
# 38     CARD                           59                     0.12
# 39    VVIMP                           34                     0.07
# 40   PTKANT                           33                     0.07
# 41     PTKA                           37                     0.07
# 42    VMINF                           33                     0.07
# 43     APZR                           28                     0.06
# 44   PRELAT                           14                     0.03
# 45       $(                            7                     0.01
# 46    VAIMP                           15                     0.03
# 47     PWAT                            8                     0.02
# 48    TRUNC                           14                     0.03
# 49     APPO                            7                     0.01
# 50      ITJ                            5                     0.01
# 51       XY                            6                     0.01
#
#     teitok: absolute count  teitok: percentage  both: average absolute count
# 0                     7209               14.50                        7377.5
# 1                     5355               10.77                        4341.0
# 2                     4161                8.37                        4161.0
# 3                     3965                7.97                        3941.0
# 4                     3843                7.73                        3848.0
# 5                     3738                7.52                        3733.5
# 6                     2972                5.98                        2975.0
# 7                     2154                4.33                        2153.5
# 8                     2132                4.29                        2150.0
# 9                     1819                3.66                        1803.0
# 10                    1600                3.22                        1625.5
# 11                    1539                3.10                        1528.5
# 12                    1477                2.97                        1460.5
# 13                    1240                2.49                        1230.0
# 14                     971                1.95                         952.5
# 15                     934                1.88                         912.0
# 16                     709                1.43                         708.5
# 17                     600                1.21                         600.0
# 18                     541                1.09                         536.5
# 19                     530                1.07                         518.0
# 20                     493                0.99                         483.0
# 21                     445                0.89                         445.0
# 22                     450                0.90                         441.0
# 23                     360                0.72                         355.0
# 24                     300                0.60                         302.0
# 25                     299                0.60                         294.0
# 26                     209                0.42                         202.0
# 27                     191                0.38                         180.0
# 28                     166                0.33                         165.0
# 29                     154                0.31                         154.0
# 30                     152                0.31                         146.0
# 31                     136                0.27                         136.5
# 32                     134                0.27                         132.5
# 33                     121                0.24                         118.0
# 34                     116                0.23                         107.0
# 35                      75                0.15                          74.5
# 36                      66                0.13                          66.0
# 37                      66                0.13                          66.0
# 38                      62                0.12                          60.5
# 39                      48                0.10                          41.0
# 40                      48                0.10                          40.5
# 41                      37                0.07                          37.0
# 42                      37                0.07                          35.0
# 43                      28                0.06                          28.0
# 44                      14                0.03                          14.0
# 45                      20                0.04                          13.5
# 46                       7                0.01                          11.0
# 47                       8                0.02                           8.0
# 48                       0                0.00                           7.0
# 49                       6                0.01                           6.5
# 50                       6                0.01                           5.5
# 51                       0                0.00                           3.0

# %% [markdown]
# # deprel (dependency relation)

# %%
convert_to_summary_df(attrib_count_xmlanntools, attrib_count_teitok, "deprel")
# Out:
#           deprel  xmlanntools: absolute count  xmlanntools: percentage  \
# 0          punct                         7445                    14.97
# 1            det                         5408                    10.88
# 2          nsubj                         4657                     9.37
# 3         advmod                         3799                     7.64
# 4           case                         3699                     7.44
# 5            obj                         3614                     7.27
# 6           root                         2869                     5.77
# 7            obl                         2676                     5.38
# 8           conj                         2563                     5.15
# 9           amod                         2023                     4.07
# 10            cc                         1779                     3.58
# 11          nmod                         1479                     2.97
# 12           aux                         1154                     2.32
# 13          mark                          950                     1.91
# 14           acl                          840                     1.69
# 15         xcomp                          565                     1.14
# 16         appos                          569                     1.14
# 17  compound:prt                          476                     0.96
# 18           cop                          449                     0.90
# 19     parataxis                          351                     0.71
# 20         ccomp                          415                     0.83
# 21     flat:name                          437                     0.88
# 22         advcl                          357                     0.72
# 23      aux:pass                          293                     0.59
# 24    nsubj:pass                          274                     0.55
# 25          iobj                          179                     0.36
# 26       expl:pv                          176                     0.35
# 27         csubj                           76                     0.15
# 28          expl                           79                     0.16
# 29        nummod                           41                     0.08
# 30          flat                           25                     0.05
# 31    csubj:pass                            7                     0.01
#
#     teitok: absolute count  teitok: percentage  both: average absolute count
# 0                     8593               17.28                        8019.0
# 1                     5386               10.83                        5397.0
# 2                     4813                9.68                        4735.0
# 3                     3826                7.69                        3812.5
# 4                     3682                7.40                        3690.5
# 5                     3673                7.39                        3643.5
# 6                     3373                6.78                        3121.0
# 7                     2675                5.38                        2675.5
# 8                     2564                5.16                        2563.5
# 9                     1983                3.99                        2003.0
# 10                    1815                3.65                        1797.0
# 11                    1460                2.94                        1469.5
# 12                    1199                2.41                        1176.5
# 13                     977                1.96                         963.5
# 14                     868                1.75                         854.0
# 15                     546                1.10                         555.5
# 16                     501                1.01                         535.0
# 17                     498                1.00                         487.0
# 18                     457                0.92                         453.0
# 19                     511                1.03                         431.0
# 20                     435                0.87                         425.0
# 21                     373                0.75                         405.0
# 22                     371                0.75                         364.0
# 23                     296                0.60                         294.5
# 24                     278                0.56                         276.0
# 25                     178                0.36                         178.5
# 26                     169                0.34                         172.5
# 27                      89                0.18                          82.5
# 28                      79                0.16                          79.0
# 29                      42                0.08                          41.5
# 30                      25                0.05                          25.0
# 31                       8                0.02                           7.5

# %% [markdown]
# # feats (various features)

# %%
feat_keys = list(set(set(attrib_count_xmlanntools["feats"].keys()) | set(attrib_count_teitok["feats"].keys())))
feat_keys = sorted(feat_keys)
for k in feat_keys:
    df_k = convert_to_summary_df(attrib_count_xmlanntools["feats"], attrib_count_teitok["feats"], k)
    display(df_k)
# Out:
#   AdpType  xmlanntools: absolute count  xmlanntools: percentage  \
# 0    Prep                         3423                    98.99
# 1    Circ                           28                     0.81
# 2    Post                            7                     0.20
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    3417               98.81                        3420.0
# 1                      28                0.81                          28.0
# 2                       6                0.17                           6.5
#   Aspect  xmlanntools: absolute count  xmlanntools: percentage  \
# 0   Perf                         1008                    100.0
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    1046              103.77                        1027.0
#   Case  xmlanntools: absolute count  xmlanntools: percentage  \
# 0  Dat                         5542                    34.41
# 1  Nom                         5118                    31.77
# 2  Acc                         4255                    26.42
# 3  Gen                         1193                     7.41
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    5513               34.23                        5527.5
# 1                    5219               32.40                        5168.5
# 2                    4276               26.55                        4265.5
# 3                    1194                7.41                        1193.5
#   ConjType  xmlanntools: absolute count  xmlanntools: percentage  \
# 0     Comp                          304                    100.0
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                     300               98.68                         302.0
#   Degree  xmlanntools: absolute count  xmlanntools: percentage  \
# 0    Pos                         3549                    90.42
# 1    Cmp                          191                     4.87
# 2    Sup                          185                     4.71
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    3549               90.42                        3549.0
# 1                     193                4.92                         192.0
# 2                     184                4.69                         184.5
#   Foreign  xmlanntools: absolute count  xmlanntools: percentage  \
# 0     Yes                           98                    100.0
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                     116              118.37                         107.0
#   Gender  xmlanntools: absolute count  xmlanntools: percentage  \
# 0   Masc                         6112                    36.87
# 1    Fem                         6424                    38.76
# 2   Neut                         4039                    24.37
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    6266               37.80                        6189.0
# 1                    5816               35.09                        6120.0
# 2                    4108               24.78                        4073.5
#   Hyph  xmlanntools: absolute count  xmlanntools: percentage  \
# 0  Yes                           14                    100.0
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                       0                 0.0                           7.0
#   Mood  xmlanntools: absolute count  xmlanntools: percentage  \
# 0  Ind                         5646                    99.14
# 1  Imp                           49                     0.86
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    5708              100.23                        5677.0
# 1                      55                0.97                          52.0
#   NumType  xmlanntools: absolute count  xmlanntools: percentage  \
# 0    Card                           59                    100.0
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                      62              105.08                          60.5
#   Number  xmlanntools: absolute count  xmlanntools: percentage  \
# 0   Sing                        21479                    80.76
# 1   Plur                         5117                    19.24
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                   21097               79.32                       21288.0
# 1                    5299               19.92                        5208.0
#   PartType  xmlanntools: absolute count  xmlanntools: percentage  \
# 0      Vbp                          506                    61.11
# 1      Inf                          289                    34.90
# 2      Res                           33                     3.99
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                     530               64.01                         518.0
# 1                     299               36.11                         294.0
# 2                      48                5.80                          40.5
#   Person  xmlanntools: absolute count  xmlanntools: percentage  \
# 0      3                        20650                    91.95
# 1      1                         1012                     4.51
# 2      2                          796                     3.54
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                   20282               90.31                       20466.0
# 1                    1085                4.83                        1048.5
# 2                     898                4.00                         847.0
#   Polarity  xmlanntools: absolute count  xmlanntools: percentage  \
# 0      Neg                          432                    100.0
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                     450              104.17                         441.0
#   Poss  xmlanntools: absolute count  xmlanntools: percentage  \
# 0  Yes                         1220                    100.0
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    1240              101.64                        1230.0
#       PronType  xmlanntools: absolute count  xmlanntools: percentage  \
# 0          Prs                         5737                    48.23
# 1          Art                         4298                    36.13
# 2          Rel                          722                     6.07
# 3  Ind,Neg,Tot                          514                     4.32
# 4          Dem                          332                     2.79
# 5          Int                          292                     2.45
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    5805               48.80                        5771.0
# 1                    4288               36.05                        4293.0
# 2                     723                6.08                         722.5
# 3                     526                4.42                         520.0
# 4                     345                2.90                         338.5
# 5                     320                2.69                         306.0
#   PunctType  xmlanntools: absolute count  xmlanntools: percentage  \
# 0      Peri                         3327                    44.39
# 1      Comm                         4161                    55.52
# 2      Brck                            7                     0.09
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    5355               71.45                        4341.0
# 1                    4161               55.52                        4161.0
# 2                      20                0.27                          13.5
#   Reflex  xmlanntools: absolute count  xmlanntools: percentage  \
# 0    Yes                          600                    100.0
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                     600               100.0                         600.0
#   Tense  xmlanntools: absolute count  xmlanntools: percentage  \
# 0  Pres                         2823                    50.12
# 1  Past                         2810                    49.88
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    2838               50.38                        2830.5
# 1                    2847               50.54                        2828.5
#   Variant  xmlanntools: absolute count  xmlanntools: percentage  \
# 0   Short                         1518                    100.0
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    1539              101.38                        1528.5
#   VerbForm  xmlanntools: absolute count  xmlanntools: percentage  \
# 0      Fin                         5695                    72.71
# 1      Inf                         1129                    14.42
# 2     Part                         1008                    12.87
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                    5763               73.58                        5729.0
# 1                    1189               15.18                        1159.0
# 2                    1046               13.36                        1027.0
#   VerbType  xmlanntools: absolute count  xmlanntools: percentage  \
# 0      Mod                          506                    100.0
#
#    teitok: absolute count  teitok: percentage  both: average absolute count
# 0                     530              104.74                         518.0
